# %%
import arcpy
import arcpy.ia

arcpy.ia.TrainDeepLearningModel(
    in_folder=r"C:\Users\ss2596\Documents\njoko training\Road_test15",
    out_folder=r"C:\Users\ss2596\Documents\Njoko_model\Road_test15_tuned",
    model_type="DEEPLAB",
    backbone_model="RESNET50",
    batch_size=4,
    chip_size=512,
    arguments="class_balancing True;focal_loss True;dice_loss_fraction 0.8;dice_loss_average micro;keep_dilation True",
    learning_rate=0.0001,
    max_epochs=80,
    stop_training="STOP_TRAINING",
    freeze="UNFREEZE_MODEL",
    augmentation="ROTATE;FLIP;BRIGHTNESS;CONTRAST;STRETCH",
    augmentation_parameters="rotation_range 0 360;flip_horizontal True;flip_vertical True;brightness 0.2;contrast 0.2;stretch 0.1",
    validation_percentage=10,
    tensorboard="ENABLE_TENSORBOARD"
)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File c:\program files\arcgis\pro\Resources\ArcToolbox\toolboxes\Image Analyst Tools.tbx\TrainDeepLearningModel.tool\tool.script.validate.py:935
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# File c:\program files\arcgis\pro\Resources\ArcToolbox\toolboxes\Image Analyst Tools.tbx\TrainDeepLearningModel.tool\tool.script.validate.py:376, in ToolValidator.updateParameters(self)
#     374 if self.params[3].value:
#     375     try:
# --> 376         import arcgis.learn
#     377         modelclass = MODEL_TO_MODELCLASS.get(self.params[3].value)
#     379         training_model = getattr(arcgis.learn, modelclass)
#
# File C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\Lib\site-packages\arcgis\learn\__init__.py:23
#      21 try:
# ...
